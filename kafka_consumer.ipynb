# %% [markdown]
# <a href="https://colab.research.google.com/github/hoonheelee0202/2020DistributedAssignment1/blob/master/kafka_consumer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install kafka-python
# Out:
# ...
#      |████████████████████████████████| 256kB 6.1MB/s
# ...

# %%
from kafka import KafkaConsumer

server_addr = '54.236.49.27'+':9092'
topic = '1_count'
#topic = '2_group'
# To consume latest messages and auto-commit offsets
consumer = KafkaConsumer(topic, bootstrap_servers=[server_addr],consumer_timeout_ms=1000,#important for stopping if there is no data
     auto_offset_reset='earliest')
for message in consumer:
    # message value and key are raw bytes -- decode if necessary!
    # e.g., for unicode: `message.value.decode('utf-8')`
    print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                          message.offset, message.key,
                                          message.value))
# Out:
# 1_count:0:0: key=None value=b'abc'
# 1_count:0:1: key=None value=b'0'
# 1_count:0:2: key=None value=b'1'
# ...
